# %% [markdown]
# ## **Paragraph:**
#
# <p style="font-size: 20px;">Indian cuisine offers a rich and diverse array of vegetarian dishes, reflecting the country's cultural and regional variations. Staples like lentils, rice, and a variety of fresh vegetables form the foundation of many meals. Dishes such as dal (lentil stew), sabzi (vegetable curry), and roti (unleavened bread) are commonplace. Spices play a crucial role, with ingredients like turmeric, cumin, coriander, and garam masala imparting unique flavors. South Indian cuisine features dishes like dosa (fermented crepe), idli (steamed rice cakes), and sambar (spicy lentil soup). North Indian cuisine is famous for dishes like paneer tikka (grilled cheese), chole (chickpea curry), and aloo gobi (potato and cauliflower curry). Street foods such as samosas, bhel puri, and pav bhaji are popular across the country. Many Indian sweets, including gulab jamun, jalebi, and barfi, are also vegetarian. Each region offers its own specialties, ensuring a vast and exciting culinary landscape for vegetarians to explore.</p>

# %% [markdown]
# ## Tasks
#
# 1. Extract the first sentence of the paragraph.
# 1. Extract the last sentence of the paragraph.
# 1. Extract the word "lentils" from the paragraph.
# 1. Extract the first five words of the paragraph.
# 1. Extract the last five words of the paragraph.
# 1. Extract the phrase "South Indian cuisine features dishes like dosa".
# 1. Extract all the words between "coriander" and "idli".
# 1. Extract the name of three North Indian dishes.
# 1. Extract the names of all South Indian dishes mentioned.
# 1. Extract the name of the first street food mentioned.
# 1. Extract the phrase "unique flavors" from the paragraph.
# 1. Extract the names of all spices mentioned in the paragraph.
# 1. Extract the phrase "Indian sweets, including gulab jamun, jalebi, and barfi".
# 1. Extract the phrase "North Indian cuisine is famous for dishes".
# 1. Extract the phrase "foundation of many meals".
# 1. Extract the first mention of the word "curry".
# 1. Extract the phrase "reflecting the country's cultural and regional variations".
# 1. Extract the phrase "North Indian cuisine is famous for dishes like paneer tikka".
# 1. Extract the phrase "spices play a crucial role".
# 1. Extract the phrase "Each region offers its own specialties".

# %%
sentences = "Indian cuisine offers a rich and diverse array of vegetarian dishes, reflecting the country's cultural and regional variations. Staples like lentils, rice, and a variety of fresh vegetables form the foundation of many meals. Dishes such as dal (lentil stew), sabzi (vegetable curry), and roti (unleavened bread) are commonplace. Spices play a crucial role, with ingredients like turmeric, cumin, coriander, and garam masala imparting unique flavors. South Indian cuisine features dishes like dosa (fermented crepe), idli (steamed rice cakes), and sambar (spicy lentil soup). North Indian cuisine is famous for dishes like paneer tikka (grilled cheese), chole (chickpea curry), and aloo gobi (potato and cauliflower curry). Street foods such as samosas, bhel puri, and pav bhaji are popular across the country. Many Indian sweets, including gulab jamun, jalebi, and barfi, are also vegetarian. Each region offers its own specialties, ensuring a vast and exciting culinary landscape for vegetarians to explore."

sentences
# Out:
# "Indian cuisine offers a rich and diverse array of vegetarian dishes, reflecting the country's cultural and regional variations. Staples like lentils, rice, and a variety of fresh vegetables form the foundation of many meals. Dishes such as dal (lentil stew), sabzi (vegetable curry), and roti (unleavened bread) are commonplace. Spices play a crucial role, with ingredients like turmeric, cumin, coriander, and garam masala imparting unique flavors. South Indian cuisine features dishes like dosa (fermented crepe), idli (steamed rice cakes), and sambar (spicy lentil soup). North Indian cuisine is famous for dishes like paneer tikka (grilled cheese), chole (chickpea curry), and aloo gobi (potato and cauliflower curry). Street foods such as samosas, bhel puri, and pav bhaji are popular across the country. Many Indian sweets, including gulab jamun, jalebi, and barfi, are also vegetarian. Each region offers its own specialties, ensuring a vast and exciting culinary landscape for vegetarians to explore."

# %%
sentences_list = sentences.split(".")
first_sentence = sentences_list[0]
last_sentence = sentences_list[-2][1:]

print(first_sentence, last_sentence, sep="\n")
# Out:
# Indian cuisine offers a rich and diverse array of vegetarian dishes, reflecting the country's cultural and regional variations
# Each region offers its own specialties, ensuring a vast and exciting culinary landscape for vegetarians to explore

# %%
sentences.find("lentils")
sentences[141 : 148]
# Out:
# 'lentils'

# %%
words = sentences.split(" ")
first_5_words = words[0:5]
last_5_words = words[-5:]

first_5_words, last_5_words
# Out:
# (['Indian', 'cuisine', 'offers', 'a', 'rich'],
#  ['landscape', 'for', 'vegetarians', 'to', 'explore.'])

# %%
l = ['apple', 'banana', 'orange']
delim = ', '

result = delim.join(l)
result
# Out:
# 'apple, banana, orange'

# %%
s = "Hello, World, World!"
w = "World"

print(s.rfind(w))
# Out:
# 14
# 'W'

# %% [markdown]
# <img src="images/1.png">

# %%
v = int(input("v = "))
c = int(input("c = "))
d = int(input("d = "))
g = int(input("g = "))

R = (2*v + 6.22 * (c + d)) / (g+v)

R
# Out:
# 7.22
