# %% [markdown]
# # Methods
# ---

# %%
veggies = [
    "Bitter Gourd (Karela)",
    "Bottle Gourd (Lauki)",
    "Ridge Gourd (Turai)",
    "Snake Gourd (Galka)",
    "Pointed Gourd (Parwal)",
    "Drumstick (Moringa)",
    "Taro Root (Arbi)",
    "Elephant Foot Yam (Suran)",
    "Ash Gourd (Petha)",
    "Ivy Gourd (Tindora)",
    "Fenugreek Leaves (Methi)",
    "Amaranth Leaves (Patra)",
    "Colocasia Leaves (Arbi ke Patte)",
    "Beet Greens (Chukandar ke Patte)",
    "Mustard Greens (Sarson)",
    "Radish Greens (Mooli ke Patte)",
    "Spinach (Palak)",
    "Fenugreek Seeds Sprouts (Methi Dana)",
    "Cluster Beans (Gawar Phali)",
    "French Beans",
    "Yardlong Beans (Bora)",
    "Broad Beans (Sem)",
    "Green Peas (Matar)",
    "Corn (Makai)",
    "Bamboo Shoots (Karil)",
    "Jackfruit (Kathal)",
    "Raw Banana (Kachcha Kela)",
    "Green Papaya (Kachcha Papita)",
    "Indian Gooseberry (Amla)",
    "Curry Leaves (Kadi Patta)",
    "Raw Mango (Keri)",
    "Sponge Gourd (Nenua)",
    "Brinjal (Baingan)",
    "Lady Finger (Bhindi)",
    "Cabbage (Patta Gobi)",
    "Cauliflower (Phool Gobi)",
    "Radish (Mooli)",
    "Turnip (Shalgam)",
    "Carrot (Gajar)",
    "Tomato (Tamatar)"
]

# %%
veggies.append("Bell Pepper (Capsicum)")
veggies

# %%
veggies.count("Corn (Makai)")
# Out:
# 1

# %%
veggies.clear()
veggies
# Out:
# []

# %%
l = veggies.copy()
print(id(veggies), id(l))
# Out:
# 1917201480704 1917201517440

# %%
l = ["Bell Pepper (Capsicum)", "Khaman (!veggie)", ["abcd", "xyz"]]
veggies.extend(l)
veggies

# %%
print(len(veggies))

veggies.insert(401, "Bell Pepper (Capsicum)")
veggies

# %%
veggies.index("Turnip (Shalgam)", -2)

# %%
veggies.pop(37)
# Out:
# 'Turnip (Shalgam)'

# %%
veggies.reverse()
veggies

# %%
veggies.remove("Raw Mango (Keri)")
veggies
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 veggies.remove("Raw Mango (Keri)")
#       2 veggies
#
# ValueError: list.remove(x): x not in list

# %%
# veggies.sort()
veggies.sort(reverse=True)
veggies
# Out:
# ['Yardlong Beans (Bora)',
#  'Tomato (Tamatar)',
#  'Taro Root (Arbi)',
#  'Sponge Gourd (Nenua)',
#  'Spinach (Palak)',
#  'Snake Gourd (Galka)',
#  'Ridge Gourd (Turai)',
#  'Raw Banana (Kachcha Kela)',
#  'Radish Greens (Mooli ke Patte)',
#  'Radish (Mooli)',
#  'Pointed Gourd (Parwal)',
#  'Mustard Greens (Sarson)',
#  'Lady Finger (Bhindi)',
#  'Jackfruit (Kathal)',
#  'Ivy Gourd (Tindora)',
#  'Indian Gooseberry (Amla)',
#  'Green Peas (Matar)',
#  'Green Papaya (Kachcha Papita)',
#  'French Beans',
#  'Fenugreek Seeds Sprouts (Methi Dana)',
#  'Fenugreek Leaves (Methi)',
#  'Elephant Foot Yam (Suran)',
#  'Drumstick (Moringa)',
#  'Curry Leaves (Kadi Patta)',
#  'Corn (Makai)',
#  'Colocasia Leaves (Arbi ke Patte)',
#  'Cluster Beans (Gawar Phali)',
#  'Cauliflower (Phool Gobi)',
#  'Carrot (Gajar)',
#  'Cabbage (Patta Gobi)',
#  'Broad Beans (Sem)',
#  'Brinjal (Baingan)',
#  'Bottle Gourd (Lauki)',
#  'Bitter Gourd (Karela)',
#  'Beet Greens (Chukandar ke Patte)',
# ...
