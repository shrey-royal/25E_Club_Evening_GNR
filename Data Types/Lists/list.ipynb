# %% [markdown]
# # List
# ---
#
# A mutable sequence
# ```python
# syntax:
# list() -> represent by []
# ```
#
# - Changeable? True
# - Duplicates Allowed? True

# %%
# mylist = []
mylist = list()

print(f"mylist = {mylist}", f"type(mylist) = {type(mylist)}", sep="\n")
# Out:
# mylist = []
# type(mylist) = <class 'list'>

# %%
# initializing Lists
fruits = ["Mango", "Apple", "Grapes", "Banana", "Orange", "Kiwi", "Dragon Fruit", "Guava", "Watermelon", "Musk Melon", "Mud Apple", "Rose Berry", "Lychee", "Blue Berry", "Black Grapes", "Peach", "Custard Apple", "Papaya", "Pineapple", "Strawberry", "Pomegranate", "Raspberry", "Avocado"]

# %%
print(fruits)
# print(fruits[2::3])
print(fruits[::-1])
# Out:
# ['Mango', 'Apple', 'Grapes', 'Banana', 'Orange', 'Kiwi', 'Dragon Fruit', 'Guava', 'Watermelon', 'Musk Melon', 'Mud Apple', 'Rose Berry', 'Lychee', 'Blue Berry', 'Black Grapes', 'Peach', 'Custard Apple', 'Papaya', 'Pineapple', 'Strawberry', 'Pomegranate', 'Raspberry', 'Avocado']
# ['Avocado', 'Raspberry', 'Pomegranate', 'Strawberry', 'Pineapple', 'Papaya', 'Custard Apple', 'Peach', 'Black Grapes', 'Blue Berry', 'Lychee', 'Rose Berry', 'Mud Apple', 'Musk Melon', 'Watermelon', 'Guava', 'Dragon Fruit', 'Kiwi', 'Orange', 'Banana', 'Grapes', 'Apple', 'Mango']

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Mango
# Apple
# Grapes
# Banana
# Orange
# Kiwi
# Dragon Fruit
# Guava
# Watermelon
# Musk Melon
# Mud Apple
# Rose Berry
# Lychee
# Blue Berry
# Black Grapes
# Peach
# Custard Apple
# Papaya
# Pineapple
# Strawberry
# Pomegranate
# Raspberry
# Avocado
